# %% [markdown]
# # <font color='red'> <center>DICCIONARIOS</center></font>
#
# Es una colección de datos mutable que organiza sus elementos de acuerdo a una llave.
#
# Llave: un elemento ÚNICO que identifica un valor asociado a esta.
#
# Cada elemento de un diccionario contiene un par llave:'valor asociado'. Cada elemento separado por comas y encerrados entre llaves.

# %%
p1 = {'Nombre':'Santiago','Edad':26,'Altura':1.86}
print(p1['Edad'])
print(type(p1))
p2 = {'Nombre':'Alejandra','Edad':31,'Altura':1.75}
print(p2)
print(type(p2))
# Out:
# 26
# <class 'dict'>
# {'Nombre': 'Alejandra', 'Edad': 31, 'Altura': 1.75}
# <class 'dict'>

# %% [markdown]
# Agreguemos una nueva llave:

# %%
p1['EPS']='Sura' # diccionario['llave']=valor
print(p1)
# Out:
# {'Nombre': 'Santiago', 'Edad': 26, 'Altura': 1.86, 'EPS': 'Sura'}

# %% [markdown]
# Modifiquemos ahora uno de sus valores:

# %%
print(p1['EPS'])
p1['EPS']='Salud total'
print(p1)
# Out:
# Sura
# {'Nombre': 'Santiago', 'Edad': 26, 'Altura': 1.86, 'EPS': 'Salud total'}

# %%
prueba = {"x":[10,20,30]}
print(prueba)
print(prueba["x"])
print(prueba["x"][0])
prueba["x"][0] = 50
print(prueba["x"])
print(prueba)
prueba["x"].append(100)
print(prueba)

# %% [markdown]
# Pasemos ahora a eliminar una de las llaves:

# %%
p1.pop('EPS')
print(p1)

# %% [markdown]
# -----
# Aclaración pop:
#
# En realidad, esta herramienta no 'destruye' el elemento si no que lo 'saca', esto quiere decir que al final este elemento puede ser reasignado a otra variable.
#
# Expliquemos esto con listas:

# %%
lista = [i+10 for i in range(11)]
print(lista)
x=lista.pop(1)
print(lista)
print(x)

# %% [markdown]
# ------
#
# Modifiquemos el nombre de una llave

# %%
p1

# %%
p1['Nombre completo']=p1.pop('Nombre')
print(p1)

# %% [markdown]
# Para determinar la cantidad de llaves de un diccionario se hace lo siguiente

# %%
cantidad = len(p1)
print(cantidad)

# %% [markdown]
# Para obtener los valores o las llaves de un diccionaro como listas se puede hacer lo siguiente:

# %%
valores=list(p1.values())
print(valores)
llaves=list(p1.keys())
print(llaves)

# %% [markdown]
# La combinación de colecciones de datos permiten crear estructuras mucho más completas:

# %%
personas=[]
print(personas)
personas.append(p1)
print(personas)
personas.append(p2)
print(personas)
print(len(personas))

# %%
print(personas[0])
print(personas[1])

# %%
print(personas[0]['Edad'])
personas[0]['Edad']=27
print(personas[0]['Edad'])

# %%
print(personas[1]['Nombre'])

# %%
personas[-1]['Altura']=1.90
print(personas)
